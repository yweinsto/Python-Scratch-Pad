# %% [markdown]
# URL: https://www.youtube.com/watch?v=1uVWjdAbgBg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('max_columns', 50)
# %matplotlib inline

# %%
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'])
s
# Out:
# 0                7
# 1       Heisenberg
# 2             3.14
# 3      -1789710578
# 4    Happy Eating!
# dtype: object

# %%
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'],
              index=['A', 'Z', 'C', 'Y', 'E'])
s
# Out:
# A                7
# Z       Heisenberg
# C             3.14
# Y      -1789710578
# E    Happy Eating!
# dtype: object

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
cities = pd.Series(d)
cities
# Out:
# Austin            450.0
# Boston              NaN
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %%
cities['Chicago']
# Out:
# 1000.0

# %%
cities[['Chicago', 'Portland', 'San Francisco']]
# Out:
# Chicago          1000.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %%
cities[cities < 1000]
# Out:
# Austin      450.0
# Portland    900.0
# dtype: float64

# %%
cities < 1000
# Out:
# Austin            True
# Boston           False
# Chicago          False
# New York         False
# Portland          True
# San Francisco    False
# dtype: bool

# %%
less_than_1000 = cities < 1000
print(less_than_1000)
print('\n')
print(cities[less_than_1000])
# Out:
# Austin            True
# Boston           False
# Chicago          False
# New York         False
# Portland          True
# San Francisco    False
# dtype: bool
#
#
# Austin      450.0
# Portland    900.0
# dtype: float64

# %%
print('Old value:', cities['Chicago'])
cities['Chicago'] = 1400
print('New value:', cities['Chicago'])
# Out:
# Old value: 1000.0
# New value: 1400.0

# %%
print(cities[cities < 1000])
print('\n')
cities[cities < 1000] = 750

print (cities[cities < 1000])
# Out:
# Austin      450.0
# Portland    900.0
# dtype: float64
#
#
# Austin      750.0
# Portland    750.0
# dtype: float64

# %%
print('Seattle' in cities)
print('San Francisco' in cities)
# Out:
# False
# True

# %%
print(cities)
print(cities / 3)
# Out:
# Austin            750.0
# Boston              NaN
# Chicago          1400.0
# New York         1300.0
# Portland          750.0
# San Francisco    1100.0
# dtype: float64
# Austin           250.000000
# Boston                  NaN
# Chicago          466.666667
# New York         433.333333
# Portland         250.000000
# San Francisco    366.666667
# dtype: float64

# %%
np.square(cities)
# Out:
# Austin            562500.0
# Boston                 NaN
# Chicago          1960000.0
# New York         1690000.0
# Portland          562500.0
# San Francisco    1210000.0
# dtype: float64

# %%
print(cities[['Chicago', 'New York', 'Portland']])
print('\n')
print(cities[['Austin', 'New York']])
print('\n')
print(cities[['Chicago', 'New York', 'Portland']] + cities[['Austin', 'New York']])
# Out:
# Chicago     1400.0
# New York    1300.0
# Portland     750.0
# dtype: float64
#
#
# Austin       750.0
# New York    1300.0
# dtype: float64
#
#
# Austin         NaN
# Chicago        NaN
# New York    2600.0
# Portland       NaN
# dtype: float64

# %%
cities.notnull()
# Out:
# Austin            True
# Boston           False
# Chicago           True
# New York          True
# Portland          True
# San Francisco     True
# dtype: bool

# %%
print(cities.isnull())
print('\n')
print(cities[cities.isnull()])
# Out:
# Austin           False
# Boston            True
# Chicago          False
# New York         False
# Portland         False
# San Francisco    False
# dtype: bool
#
#
# Boston   NaN
# dtype: float64

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %%
# !head -n 5 data/mariano-rivera.csv
# Out:
# Year,Age,Tm,Lg,W,L,W-L%,ERA,G,GS,GF,CG,SHO,SV,IP,H,R,ER,HR,BB,IBB,SO,HBP,BK,WP,BF,ERA+,FIP,WHIP,H9,HR9,BB9,SO9,SO/W,Awards
# 1995,25,NYY,AL,5,3,0.625,5.51,19,10,2,0,0,0,67,71,43,41,11,30,0,51,2,1,0,301,84,5.15,1.507,9.5,1.5,4,6.9,1.7,
# 1996,26,NYY,AL,8,3,0.727,2.09,61,0,14,0,0,5,107.2,73,25,25,1,34,3,130,2,0,1,425,240,1.88,0.994,6.1,0.1,2.8,10.9,3.82,CYA-3MVP-12
# 1997,27,NYY,AL,6,4,0.6,1.88,66,0,56,0,0,43,71.2,65,17,15,5,20,6,68,0,0,2,301,239,2.96,1.186,8.2,0.6,2.5,8.5,3.4,ASMVP-25
# 1998,28,NYY,AL,3,0,1,1.91,54,0,49,0,0,36,61.1,48,13,13,3,17,1,36,1,0,0,246,233,3.48,1.06,7,0.4,2.5,5.3,2.12,

# %%
from_csv = pd.read_csv('data/mariano-rivera.csv')
from_csv.head()
# Out:
#    Year Age   Tm  Lg  W  L   W-L%   ERA   G  GS  GF CG SHO  SV     IP   H   R  \
# 0  1995  25  NYY  AL  5  3  0.625  5.51  19  10   2  0   0   0     67  71  43
# 1  1996  26  NYY  AL  8  3  0.727  2.09  61   0  14  0   0   5  107.2  73  25
# 2  1997  27  NYY  AL  6  4    0.6  1.88  66   0  56  0   0  43   71.2  65  17
# 3  1998  28  NYY  AL  3  0      1  1.91  54   0  49  0   0  36   61.1  48  13
# 4  1999  29  NYY  AL  4  3  0.571  1.83  66   0  63  0   0  45     69  43  15
#
#    ER  HR  BB IBB   SO HBP BK WP   BF ERA+   FIP   WHIP   H9  HR9  BB9   SO9  \
# 0  41  11  30   0   51   2  1  0  301   84  5.15  1.507  9.5  1.5    4   6.9
# 1  25   1  34   3  130   2  0  1  425  240  1.88  0.994  6.1  0.1  2.8  10.9
# 2  15   5  20   6   68   0  0  2  301  239  2.96  1.186  8.2  0.6  2.5   8.5
# 3  13   3  17   1   36   1  0  0  246  233  3.48   1.06    7  0.4  2.5   5.3
# 4  14   2  18   3   52   3  1  2  268  257  2.92  0.884  5.6  0.3  2.3   6.8
#
#    SO/W         Awards
# 0   1.7            NaN
# 1  3.82    CYA-3MVP-12
# 2   3.4       ASMVP-25
# 3  2.12            NaN
# 4  2.89  ASCYA-3MVP-14

# %%
# 11  60  81  0.318  0.379  0.560  0.938   161  319   15    1   0   8  10.0
# 12  76  96  0.279  0.356  0.539  0.895   142  325   14    1   0   8  15.0
# 13  63  97  0.307  0.369  0.573  0.943   168  344   11    0   0   6  19.0
# 14  64  62  0.287  0.354  0.498  0.852   153  302   21    1   0   5  23.0
# 15  87  47  0.300  0.396  0.607  1.003   177  332   14    2   0   3  19.0
# 16  74  63  0.298  0.385  0.574  0.958   149  296   13    2   0   6  15.0
# 17  71  58  0.327  0.410  0.669  1.079   194  331    9    2   0   5  21.0
# 18  92  55  0.265  0.390  0.514  0.904   147  231   17    1   0   2  15.0
# 19  68  51  0.301  0.402  0.643  1.045   177  252    7    1   0   4  13.0
# 20  39  29  0.268  0.341  0.491  0.832   128  167    6    0   1   2   6.0
# 21  70  51  0.234  0.332  0.355  0.687    95  165   15    1   1   6   3.0
# 22  35  38  0.229  0.315  0.369  0.684   102  100    8    0   0   2   1.0
#
#       Pos        Awards
# 0     *79         RoY-4
# 1    *974      AS,MVP-9
# 2      *9      AS,MVP-3
# 3     *98      AS,MVP-1
# 4     *98   AS,MVP-3,GG
# 5   *98/5   AS,MVP-3,GG
# 6   *9/84  AS,MVP-11,GG
# 7   *89/5      AS,MVP-8
# 8   *89/3      AS,MVP-6
# 9      *9      AS,MVP-3
# 10    *94     AS,MVP-14
# 11     *9      AS,MVP-7
# 12  *9/84      AS,MVP-8
# 13  *98/4      AS,MVP-5
# 14    *93     AS,MVP-12
# 15   *9/3      AS,MVP-3
# 16    *93     AS,MVP-17
# 17     39      AS,MVP-3
# 18    *39     AS,MVP-16
# 19     79     AS,MVP-12
# 20      7            AS
# 21   *D/7            AS
# 22    D/7           NaN

# %%
url = 'https://raw.github.com/gjreda/best-sandwiches/master/data/best-sandwiches-geocode.tsv'

# fetch the text from the URL and read it into a DataFrame
from_url = pd.read_table(url, sep='\t')
from_url.head(3)
# Out:
#    rank           sandwich   restaurant  \
# 0     1                BLT  Old Oak Tap
# 1     2      Fried Bologna    Au Cheval
# 2     3  Woodland Mushroom         Xoco
#
#                                          description   price  \
# 0  The B is applewood smoked&mdash;nice and snapp...     $10
# 1  Thought your bologna-eating days had retired w...      $9
# 2  Leave it to Rick Bayless and crew to come up w...  $9.50.
#
#                 address     city         phone              website  \
# 0  2109 W. Chicago Ave.  Chicago  773-772-0406     theoldoaktap.com
# 1   800 W. Randolph St.  Chicago  312-929-4580  aucheval.tumblr.com
# 2      445 N. Clark St.  Chicago  312-334-3688      rickbayless.com
#
#                     full_address  \
# 0  2109 W. Chicago Ave., Chicago
# 1   800 W. Randolph St., Chicago
# 2      445 N. Clark St., Chicago
#
#                                   formatted_address        lat        lng
# 0  2109 West Chicago Avenue, Chicago, IL 60622, USA  41.895734 -87.679960
# 1  800 West Randolph Street, Chicago, IL 60607, USA  41.884672 -87.647754
# 2    445 North Clark Street, Chicago, IL 60654, USA  41.890602 -87.630925
